# %% [markdown]
# # Project 4
# ______

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Loading and Cleaning Dataset
# ____

# %%
covid = pd.read_csv('../data/COVID/United_States_COVID-19_Cases_and_Deaths_by_State_over_Time.csv')
covid['submission_date'] = pd.to_datetime(covid['submission_date'])
covid.set_index('submission_date', inplace=True)
covid.head()
# Out:
#                 state  tot_cases conf_cases prob_cases new_case pnew_case  \
# submission_date
# 2020-01-25         OR          0        NaN        NaN        0       NaN
# 2021-09-17         MD    516,784        NaN        NaN    1,525         0
# 2021-10-12         VT     33,388        NaN        NaN      112         5
# 2021-02-01         DC     37,008        NaN        NaN      136         0
# 2021-12-19         NC  1,586,243  1,339,055    247,188    3,410       466
#
#                 tot_death conf_death prob_death new_death pnew_death  \
# submission_date
# 2020-01-25              0        NaN        NaN         0        NaN
# 2021-09-17         10,282     10,056        226        11          0
# 2021-10-12            333        NaN        NaN         4          0
# 2021-02-01            916        NaN        NaN         3          0
# 2021-12-19         19,480     17,148      2,332        19          3
#
#                              created_at consent_cases consent_deaths
# submission_date
# 2020-01-25       03/26/2020 04:22:39 PM         Agree          Agree
# 2021-09-17       09/19/2021 12:00:00 AM           NaN          Agree
# 2021-10-12       10/14/2021 12:00:00 AM     Not agree      Not agree
# 2021-02-01       02/02/2021 02:51:51 PM           NaN            NaN
# 2021-12-19       12/19/2021 12:00:00 AM         Agree          Agree
