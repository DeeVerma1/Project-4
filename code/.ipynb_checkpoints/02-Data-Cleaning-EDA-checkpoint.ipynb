# %% [markdown]
# # Project 4
# ______

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msno

# %% [markdown]
# ### Covid surveillance data

# %%
#setting options to be able to see whole text in dataframe columns
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.set_option('max_colwidth',800)

# %%
# url='https://drive.google.com/file/d/1muBh32vAqHnyTnir-kW0bvnVTqd2k6ZC/view?usp=sharing'
# dnld_link='https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
# print(dnld_link)

# %%
# df_surv=pd.read_csv(dnld_link)

# %%
df_surv=pd.read_csv('../data/covid_surveillance.csv')

# %%
df_surv.head()
# Out:
#   case_month res_state  state_fips_code   res_county  county_fips_code  \
# 0    2022-05        KY               21    JEFFERSON           21111.0
# 1    2022-01        WI               55       RACINE           55101.0
# 2    2022-01        LA               22        CADDO           22017.0
# 3    2021-04        FL               12          LEE           12071.0
# 4    2021-08        NC               37  NEW HANOVER           37129.0
#
#         age_group     sex     race            ethnicity  \
# 0       65+ years  Female    White  Non-Hispanic/Latino
# 1  50 to 64 years    Male    White  Non-Hispanic/Latino
# 2  18 to 49 years  Female  Unknown              Unknown
# 3  18 to 49 years  Female      NaN                  NaN
# 4    0 - 17 years  Female    White      Hispanic/Latino
#
#    case_positive_specimen  process exposure_yn             current_status  \
# 0                     0.0  Missing     Missing              Probable Case
# 1                     NaN  Missing     Missing  Laboratory-confirmed case
# 2                     0.0  Missing     Missing  Laboratory-confirmed case
# 3                   -10.0  Missing     Missing  Laboratory-confirmed case
# 4                     0.0  Missing     Unknown              Probable Case
#
#   symptom_status  hosp_yn   icu_yn death_yn  case_onset_interval  \
# 0        Missing       No  Missing       No                  NaN
# 1        Missing  Unknown  Missing  Unknown                  NaN
# 2        Unknown  Unknown  Unknown  Missing                  NaN
# 3    Symptomatic       No  Missing       No                  0.0
# 4    Symptomatic       No  Unknown       No                  0.0
#
#   underlying_conditions_yn
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
df_surv.shape
# Out:
# (500000, 19)

# %%
df_surv.head()
# Out:
#   case_month res_state  state_fips_code   res_county  county_fips_code  \
# 0    2022-05        KY               21    JEFFERSON           21111.0
# 1    2022-01        WI               55       RACINE           55101.0
# 2    2022-01        LA               22        CADDO           22017.0
# 3    2021-04        FL               12          LEE           12071.0
# 4    2021-08        NC               37  NEW HANOVER           37129.0
#
#         age_group     sex     race            ethnicity  \
# 0       65+ years  Female    White  Non-Hispanic/Latino
# 1  50 to 64 years    Male    White  Non-Hispanic/Latino
# 2  18 to 49 years  Female  Unknown              Unknown
# 3  18 to 49 years  Female      NaN                  NaN
# 4    0 - 17 years  Female    White      Hispanic/Latino
#
#    case_positive_specimen  process exposure_yn             current_status  \
# 0                     0.0  Missing     Missing              Probable Case
# 1                     NaN  Missing     Missing  Laboratory-confirmed case
# 2                     0.0  Missing     Missing  Laboratory-confirmed case
# 3                   -10.0  Missing     Missing  Laboratory-confirmed case
# 4                     0.0  Missing     Unknown              Probable Case
#
#   symptom_status  hosp_yn   icu_yn death_yn  case_onset_interval  \
# 0        Missing       No  Missing       No                  NaN
# 1        Missing  Unknown  Missing  Unknown                  NaN
# 2        Unknown  Unknown  Unknown  Missing                  NaN
# 3    Symptomatic       No  Missing       No                  0.0
# 4    Symptomatic       No  Unknown       No                  0.0
#
#   underlying_conditions_yn
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
df_surv.isnull().sum()
# Out:
# case_month                       0
# res_state                        0
# state_fips_code                  0
# res_county                     871
# county_fips_code               871
# age_group                     3024
# sex                           7959
# race                         64748
# ethnicity                    75698
# case_positive_specimen      270451
# process                          0
# exposure_yn                      0
# current_status                   0
# symptom_status                   0
# hosp_yn                          0
# icu_yn                           0
# death_yn                     18368
# case_onset_interval         291941
# underlying_conditions_yn    483518
# dtype: int64

# %%
# Dropping state_fips_code, county_fips_code, case_positive_specimen
df_surv.drop(columns=['state_fips_code', 'county_fips_code', 'case_positive_specimen'], inplace=True)

# %%
msno.matrix(df_surv);

# %%
df_surv.isnull().sum();

# %%
#no. of states in the dataset
len(df_surv['res_state'].unique())
# Out:
# 49

# %%
df_surv.head()
# Out:
#   case_month res_state   res_county       age_group     sex     race  \
# 0    2022-05        KY    JEFFERSON       65+ years  Female    White
# 1    2022-01        WI       RACINE  50 to 64 years    Male    White
# 2    2022-01        LA        CADDO  18 to 49 years  Female  Unknown
# 3    2021-04        FL          LEE  18 to 49 years  Female      NaN
# 4    2021-08        NC  NEW HANOVER    0 - 17 years  Female    White
#
#              ethnicity  process exposure_yn             current_status  \
# 0  Non-Hispanic/Latino  Missing     Missing              Probable Case
# 1  Non-Hispanic/Latino  Missing     Missing  Laboratory-confirmed case
# 2              Unknown  Missing     Missing  Laboratory-confirmed case
# 3                  NaN  Missing     Missing  Laboratory-confirmed case
# 4      Hispanic/Latino  Missing     Unknown              Probable Case
#
#   symptom_status  hosp_yn   icu_yn death_yn  case_onset_interval  \
# 0        Missing       No  Missing       No                  NaN
# 1        Missing  Unknown  Missing  Unknown                  NaN
# 2        Unknown  Unknown  Unknown  Missing                  NaN
# 3    Symptomatic       No  Missing       No                  0.0
# 4    Symptomatic       No  Unknown       No                  0.0
#
#   underlying_conditions_yn
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
df_surv.tail();

# %% [markdown]
# The surveillance data is from January 2020 to September 2022

# %%
df_surv.dtypes
# Out:
# case_month                   object
# res_state                    object
# res_county                   object
# age_group                    object
# sex                          object
# race                         object
# ethnicity                    object
# process                      object
# exposure_yn                  object
# current_status               object
# symptom_status               object
# hosp_yn                      object
# icu_yn                       object
# death_yn                     object
# case_onset_interval         float64
# underlying_conditions_yn     object
# dtype: object

# %%
df_surv['current_status'].value_counts()
# Out:
# Laboratory-confirmed case    413088
# Probable Case                 86912
# Name: current_status, dtype: int64

# %%
df_surv['age_group'].value_counts()
# Out:
# 18 to 49 years    260410
# 50 to 64 years     89260
# 0 - 17 years       79883
# 65+ years          62161
# Missing             5262
# Name: age_group, dtype: int64

# %%
df_surv['ethnicity'].value_counts()
# Out:
# Non-Hispanic/Latino    269710
# Unknown                 87237
# Hispanic/Latino         34103
# Missing                 33252
# Name: ethnicity, dtype: int64

# %%
df_surv['race'].value_counts()
# Out:
# White                                     268251
# Unknown                                    62907
# Black                                      49195
# Missing                                    36247
# Asian                                       7746
# Multiple/Other                              7063
# American Indian/Alaska Native               3684
# Native Hawaiian/Other Pacific Islander       159
# Name: race, dtype: int64

# %%
df_surv['process'].value_counts()
# Out:
# Missing                            480591
# Clinical evaluation                  9660
# Laboratory reported                  4206
# Routine surveillance                 1476
# Unknown                              1234
# Contact tracing of case patient      1008
# Multiple                              960
# Provider reported                     612
# Other                                 251
# Autopsy                                 2
# Name: process, dtype: int64

# %%
df_surv['exposure_yn'].value_counts()
# Out:
# Missing    465931
# Yes         22616
# Unknown     11453
# Name: exposure_yn, dtype: int64

# %%
df_surv['symptom_status'].value_counts()
# Out:
# Missing         238717
# Symptomatic     195669
# Unknown          60279
# Asymptomatic      5335
# Name: symptom_status, dtype: int64

# %%
df_surv['hosp_yn'].value_counts()
# Out:
# Missing    222775
# No         163411
# Unknown     98627
# Yes         15187
# Name: hosp_yn, dtype: int64

# %%
df_surv['icu_yn'].value_counts()
# Out:
# Missing    413879
# Unknown     73333
# No          11936
# Yes           852
# Name: icu_yn, dtype: int64

# %%
df_surv['death_yn'].value_counts()
# Out:
# Missing    221094
# No         177586
# Unknown     81179
# Yes          1773
# Name: death_yn, dtype: int64

# %%
df_surv['underlying_conditions_yn'].value_counts()
# Out:
# Yes    16077
# No       405
# Name: underlying_conditions_yn, dtype: int64

# %%
#dropping some more columns
df_surv.drop(columns=['process','exposure_yn','case_onset_interval','underlying_conditions_yn'], inplace=True)

# %%
df_surv_master=df_surv.copy()

# %%
df_surv.isnull().sum()
# Out:
# case_month            0
# res_state             0
# res_county          871
# age_group          3024
# sex                7959
# race              64748
# ethnicity         75698
# current_status        0
# symptom_status        0
# hosp_yn               0
# icu_yn                0
# death_yn          18368
# dtype: int64

# %%
# df_surv.to_csv('../data/clean_data/covid_surveillance_clean.csv', index=False)

# %%
#Dropping county

df_surv.drop(columns=['res_county'], inplace=True)

# %%
df_surv.dropna(inplace=True)

# %%
df_surv.shape
# Out:
# (412936, 11)

# %%
df_surv.isnull().sum()
# Out:
# case_month        0
# res_state         0
# age_group         0
# sex               0
# race              0
# ethnicity         0
# current_status    0
# symptom_status    0
# hosp_yn           0
# icu_yn            0
# death_yn          0
# dtype: int64

# %%
#converting case_month to DateTime
df_surv['case_month']=pd.to_datetime(df_surv['case_month'])

# %%
list_of_columns_to_survey= df_surv.columns

for col_name in list_of_columns_to_survey:
    print('------  VALUE COUNTS ------------------')
    print(f'Column name: {col_name}')
    print(df_surv[col_name].value_counts())
    print('----------------------------------------')
# Out:
# ------  VALUE COUNTS ------------------
# Column name: case_month
# 2022-01-01    79129
# 2021-12-01    38842
# 2020-12-01    29308
# 2021-01-01    25475
# 2020-11-01    21903
# 2021-09-01    21459
# 2022-06-01    19028
# 2021-08-01    17478
# 2022-07-01    14882
# 2022-05-01    14090
# 2021-11-01    13948
# 2022-02-01    13371
# 2022-08-01    12921
# 2021-10-01     9633
# 2021-04-01     8362
# 2021-02-01     8319
# 2020-10-01     7260
# 2021-03-01     7239
# 2022-04-01     6597
# 2020-07-01     6332
# 2020-08-01     5967
# 2020-06-01     4568
# 2021-07-01     4456
# 2021-05-01     4182
# 2022-09-01     3923
# 2022-03-01     3871
# 2020-09-01     3673
# 2021-06-01     1938
# 2020-04-01     1895
# 2020-05-01     1839
# 2020-03-01     1048
# Name: case_month, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: res_state
# TX    26791
# NC    22201
# PA    22135
# CA    21691
# FL    20441
# OH    20427
# NY    18046
# IL    16886
# GA    15496
# NJ    14973
# MI    14185
# IN    13972
# TN    12669
# SC    12567
# WI    11388
# LA    11194
# WA     9779
# MD     9671
# VA     9266
# MN     9158
# AL     8167
# MO     8129
# CO     7840
# AZ     7464
# MA     6587
# OR     5433
# UT     4996
# AR     4929
# NM     4720
# KS     3825
# ID     3703
# CT     3247
# NH     3038
# KY     3033
# ME     3014
# MT     2511
# RI     2386
# OK     2058
# DE     1956
# NE     1743
# ND     1740
# NV     1669
# HI     1627
# AK     1575
# SD     1478
# IA     1366
# WY      745
# VT      647
# DC      374
# Name: res_state, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: age_group
# 18 to 49 years    226532
# 50 to 64 years     72701
# 0 - 17 years       60208
# 65+ years          48668
# Missing             4827
# Name: age_group, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: sex
# Female     216977
# Male       191513
# Unknown      3742
# Missing       704
# Name: sex, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: race
# White                                     258077
# Unknown                                    59881
# Black                                      45213
# Missing                                    35015
# Asian                                       6808
# Multiple/Other                              4555
# American Indian/Alaska Native               3256
# Native Hawaiian/Other Pacific Islander       131
# Name: race, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: ethnicity
# Non-Hispanic/Latino    262518
# Unknown                 84922
# Missing                 33046
# Hispanic/Latino         32450
# Name: ethnicity, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: current_status
# Laboratory-confirmed case    339598
# Probable Case                 73338
# Name: current_status, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: symptom_status
# Missing         201938
# Symptomatic     160046
# Unknown          46810
# Asymptomatic      4142
# Name: symptom_status, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: hosp_yn
# Missing    186852
# No         133293
# Unknown     82062
# Yes         10729
# Name: hosp_yn, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: icu_yn
# Missing    342316
# Unknown     60365
# No           9774
# Yes           481
# Name: icu_yn, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: death_yn
# Missing    187451
# No         151470
# Unknown     72346
# Yes          1669
# Name: death_yn, dtype: int64
# ----------------------------------------

# %%
df_surv.head()
# Out:
#   case_month res_state       age_group     sex                           race  \
# 0 2022-05-01        KY       65+ years  Female                          White
# 1 2022-01-01        WI  50 to 64 years    Male                          White
# 2 2022-01-01        LA  18 to 49 years  Female                        Unknown
# 4 2021-08-01        NC    0 - 17 years  Female                          White
# 5 2021-09-01        AZ  50 to 64 years    Male  American Indian/Alaska Native
#
#              ethnicity             current_status symptom_status  hosp_yn  \
# 0  Non-Hispanic/Latino              Probable Case        Missing       No
# 1  Non-Hispanic/Latino  Laboratory-confirmed case        Missing  Unknown
# 2              Unknown  Laboratory-confirmed case        Unknown  Unknown
# 4      Hispanic/Latino              Probable Case    Symptomatic       No
# 5  Non-Hispanic/Latino  Laboratory-confirmed case        Missing  Missing
#
#     icu_yn death_yn
# 0  Missing       No
# 1  Missing  Unknown
# 2  Unknown  Missing
# 4  Unknown       No
# 5  Missing  Missing

# %%
#setting case_month as index
df_surv.set_index('case_month', inplace=True)

# %%
# sorting index
df_surv.sort_index(inplace=True)

# %%
df_surv.head()
# Out:
#            res_state       age_group     sex   race            ethnicity  \
# case_month
# 2020-03-01        PA  18 to 49 years  Female  White  Non-Hispanic/Latino
# 2020-03-01        LA       65+ years    Male  Black  Non-Hispanic/Latino
# 2020-03-01        NJ  18 to 49 years  Female  Black  Non-Hispanic/Latino
# 2020-03-01        PA  18 to 49 years  Female  White  Non-Hispanic/Latino
# 2020-03-01        MI  18 to 49 years  Female  White  Non-Hispanic/Latino
#
#                        current_status symptom_status  hosp_yn   icu_yn  \
# case_month
# 2020-03-01  Laboratory-confirmed case    Symptomatic  Unknown  Unknown
# 2020-03-01  Laboratory-confirmed case        Unknown  Unknown  Unknown
# 2020-03-01  Laboratory-confirmed case    Symptomatic  Missing  Missing
# 2020-03-01  Laboratory-confirmed case    Symptomatic       No       No
# 2020-03-01              Probable Case    Symptomatic       No  Missing
#
#            death_yn
# case_month
# 2020-03-01  Unknown
# 2020-03-01  Missing
# 2020-03-01       No
# 2020-03-01       No
# 2020-03-01       No

# %%
df_surv.tail()
# Out:
#            res_state       age_group     sex     race            ethnicity  \
# case_month
# 2022-09-01        PA       65+ years  Female    White  Non-Hispanic/Latino
# 2022-09-01        OH    0 - 17 years    Male    White  Non-Hispanic/Latino
# 2022-09-01        MI    0 - 17 years  Female    White  Non-Hispanic/Latino
# 2022-09-01        NC  50 to 64 years    Male    White              Unknown
# 2022-09-01        CO       65+ years  Female  Missing  Non-Hispanic/Latino
#
#                        current_status symptom_status  hosp_yn   icu_yn  \
# case_month
# 2022-09-01  Laboratory-confirmed case    Symptomatic  Unknown  Unknown
# 2022-09-01  Laboratory-confirmed case    Symptomatic  Missing  Missing
# 2022-09-01  Laboratory-confirmed case        Missing  Missing  Missing
# 2022-09-01              Probable Case        Unknown  Unknown  Unknown
# 2022-09-01  Laboratory-confirmed case        Missing  Missing  Missing
#
#            death_yn
# case_month
# 2022-09-01  Unknown
# 2022-09-01       No
# 2022-09-01  Unknown
# 2022-09-01       No
# 2022-09-01  Missing

# %%
def prob_case(groupby_col_name):
    prob_case=pd.DataFrame(df_surv[df_surv['current_status']=='Probable Case'].groupby(groupby_col_name).count().iloc[:,0])
    prob_case.reset_index(inplace=True)
    prob_case.columns=[groupby_col_name,'count']
    return prob_case

# %%
def conf_case(groupby_col_name):    
    conf_case=pd.DataFrame(df_surv[df_surv['current_status']=='Laboratory-confirmed case'].groupby(groupby_col_name).count().iloc[:,0])
    conf_case.reset_index(inplace=True)
    conf_case.columns=[groupby_col_name,'count']
    return conf_case

# %%
prob_case_sex=prob_case('sex')
prob_case_sex
# Out:
#        sex  count
# 0   Female  38894
# 1     Male  32536
# 2  Missing    426
# 3  Unknown   1482

# %%
conf_case_sex=conf_case('sex')
conf_case_sex
# Out:
#        sex   count
# 0   Female  178083
# 1     Male  158977
# 2  Missing     278
# 3  Unknown    2260

# %%
def bar_plot(df1_x, df1_y,df2_x,df2_y):

    figure, ax=plt.subplots(nrows=1, ncols=2, sharey=True)
    ax[0]=plt.subplot(1,2,1)
    ax[0]=plt.bar( x=df1_x, height=df1_y)
    plt.xticks(rotation=60);
    # plt.ylim(0,250000)

    ax[1]=plt.subplot(1,2,2)
    ax[1]=plt.bar( x=df2_x, height=df2_y)

    plt.xticks(rotation=60);
    # plt.ylim(0,250000);

    plt.subplots_adjust(hspace=0);
    plt.subplots_adjust( wspace=0.1);
    # left=0.2, right=0.9, top=0.9, bottom=0.1,

# %%
bar_plot(prob_case_sex['sex'], prob_case_sex['count'], conf_case_sex['sex'], conf_case_sex['count'])

# %%
prob_case_age =prob_case('age_group')
prob_case_age
# Out:
#         age_group  count
# 0    0 - 17 years  12677
# 1  18 to 49 years  41183
# 2  50 to 64 years  11211
# 3       65+ years   7192
# 4         Missing   1075

# %%
conf_case_age =conf_case('age_group')
conf_case_age
# Out:
#         age_group   count
# 0    0 - 17 years   47531
# 1  18 to 49 years  185349
# 2  50 to 64 years   61490
# 3       65+ years   41476
# 4         Missing    3752

# %%
bar_plot(prob_case_age['age_group'], prob_case_age['count'], conf_case_age['age_group'], conf_case_age['count'])

# %% [markdown]
# **compare with population percentage of age groups**

# %%
prob_case_race = prob_case('race')
prob_case_race
# Out:
#                                      race  count
# 0           American Indian/Alaska Native    213
# 1                                   Asian   1061
# 2                                   Black   6796
# 3                                 Missing   5365
# 4                          Multiple/Other    639
# 5  Native Hawaiian/Other Pacific Islander     31
# 6                                 Unknown  11746
# 7                                   White  47487

# %%
conf_case_race = conf_case('race')
conf_case_race
# Out:
#                                      race   count
# 0           American Indian/Alaska Native    3043
# 1                                   Asian    5747
# 2                                   Black   38417
# 3                                 Missing   29650
# 4                          Multiple/Other    3916
# 5  Native Hawaiian/Other Pacific Islander     100
# 6                                 Unknown   48135
# 7                                   White  210590

# %%
bar_plot(prob_case_race['race'], prob_case_race['count'], conf_case_race['race'], conf_case_race['count'])

# %%
prob_case_eth = prob_case('ethnicity')
prob_case_eth
# Out:
#              ethnicity  count
# 0      Hispanic/Latino   4479
# 1              Missing   8633
# 2  Non-Hispanic/Latino  46015
# 3              Unknown  14211

# %%
conf_case_eth = conf_case('ethnicity')
conf_case_eth
# Out:
#              ethnicity   count
# 0      Hispanic/Latino   27971
# 1              Missing   24413
# 2  Non-Hispanic/Latino  216503
# 3              Unknown   70711

# %%
bar_plot(prob_case_eth['ethnicity'], prob_case_eth['count'], conf_case_eth['ethnicity'], conf_case_eth['count'])

# %%
prob_case_state=prob_case('res_state')
prob_case_state
# Out:
#    res_state  count
# 0         AK     51
# 1         AL   2035
# 2         AR   1336
# 3         AZ   1058
# 4         CA   2537
# 5         CO    724
# 6         CT    298
# 7         DE    290
# 8         FL   2029
# 9         GA   4291
# 10        HI    107
# 11        IA    197
# 12        ID    836
# 13        IL   2811
# 14        IN   2862
# 15        KS    709
# 16        KY    871
# 17        LA   3237
# 18        MA    731
# 19        MD   2480
# 20        ME    551
# 21        MI    914
# 22        MN   1754
# 23        MO   1799
# 24        MT    408
# 25        NC   4199
# 26        ND    532
# 27        NE    570
# 28        NH    921
# 29        NJ   2506
# 30        NM      1
# 31        NV     58
# 32        NY    863
# 33        OH   5023
# 34        OK    352
# 35        OR    127
# 36        PA   4403
# 37        RI    571
# 38        SC   2587
# 39        SD    158
# 40        TN   3522
# 41        TX   6237
# 42        UT      3
# 43        VA   2404
# 44        VT     20
# 45        WA   1741
# 46        WI   1353
# 47        WY    271

# %%
conf_case_state=conf_case('res_state')
conf_case_state
# Out:
#    res_state  count
# 0         AK   1524
# 1         AL   6132
# 2         AR   3593
# 3         AZ   6406
# 4         CA  19154
# 5         CO   7116
# 6         CT   2949
# 7         DC    374
# 8         DE   1666
# 9         FL  18412
# 10        GA  11205
# 11        HI   1520
# 12        IA   1169
# 13        ID   2867
# 14        IL  14075
# 15        IN  11110
# 16        KS   3116
# 17        KY   2162
# 18        LA   7957
# 19        MA   5856
# 20        MD   7191
# 21        ME   2463
# 22        MI  13271
# 23        MN   7404
# 24        MO   6330
# 25        MT   2103
# 26        NC  18002
# 27        ND   1208
# 28        NE   1173
# 29        NH   2117
# 30        NJ  12467
# 31        NM   4719
# 32        NV   1611
# 33        NY  17183
# 34        OH  15404
# 35        OK   1706
# 36        OR   5306
# 37        PA  17732
# 38        RI   1815
# 39        SC   9980
# 40        SD   1320
# 41        TN   9147
# 42        TX  20554
# 43        UT   4993
# 44        VA   6862
# 45        VT    627
# 46        WA   8038
# 47        WI  10035
# 48        WY    474

# %%
bar_plot(prob_case_state['res_state'], prob_case_state['count'], conf_case_state['res_state'], conf_case_state['count'])

# %% [markdown]
# dropping probable and confirmed case column

# %%
df_surv.head()
# Out:
#            res_state       age_group     sex   race            ethnicity  \
# case_month
# 2020-03-01        PA  18 to 49 years  Female  White  Non-Hispanic/Latino
# 2020-03-01        LA       65+ years    Male  Black  Non-Hispanic/Latino
# 2020-03-01        NJ  18 to 49 years  Female  Black  Non-Hispanic/Latino
# 2020-03-01        PA  18 to 49 years  Female  White  Non-Hispanic/Latino
# 2020-03-01        MI  18 to 49 years  Female  White  Non-Hispanic/Latino
#
#                        current_status symptom_status  hosp_yn   icu_yn  \
# case_month
# 2020-03-01  Laboratory-confirmed case    Symptomatic  Unknown  Unknown
# 2020-03-01  Laboratory-confirmed case        Unknown  Unknown  Unknown
# 2020-03-01  Laboratory-confirmed case    Symptomatic  Missing  Missing
# 2020-03-01  Laboratory-confirmed case    Symptomatic       No       No
# 2020-03-01              Probable Case    Symptomatic       No  Missing
#
#            death_yn
# case_month
# 2020-03-01  Unknown
# 2020-03-01  Missing
# 2020-03-01       No
# 2020-03-01       No
# 2020-03-01       No

# %%
df_surv1=df_surv.drop(columns='current_status')

# %%
df_surv1.groupby('sex').count()
# Out:
#          res_state  age_group    race  ethnicity  symptom_status  hosp_yn  \
# sex
# Female      216977     216977  216977     216977          216977   216977
# Male        191513     191513  191513     191513          191513   191513
# Missing        704        704     704        704             704      704
# Unknown       3742       3742    3742       3742            3742     3742
#
#          icu_yn  death_yn
# sex
# Female   216977    216977
# Male     191513    191513
# Missing     704       704
# Unknown    3742      3742

# %%
#Help from https://stackoverflow.com/questions/37947479/pandas-sum-two-rows-of-dataframe-without-rearranging-dataframe

def case_count(col_name):
    case_count=pd.DataFrame(df_surv1[col_name].value_counts())
    case_count['percent']=df_surv1[col_name].value_counts(normalize=True)
    try:
        case_count.loc['Unknown'] +=case_count.loc['Missing']
        case_count.drop(['Missing'], inplace=True)
    except:
        pass
    case_count.reset_index(inplace=True)
    case_count.columns=[col_name,'count','percent']
    try:
        case_count[col_name]=case_count[col_name].map(lambda x: 'Unknown/Missing' if x=='Unknown' else x)
    except:
        pass
    case_count.loc['Total']=[case_count[x].sum() if case_count[x].dtype not in ['object'] else 'Total' for x in case_count.columns]
    return case_count

# %%
def bar_plot2(df):

    figure, ax=plt.subplots(nrows=1, ncols=2, sharey=False)
    ax[0]=plt.subplot(1,2,1)
    ax[0]=plt.bar( x=df.iloc[:-1,0], height=df.iloc[:-1,1])
    plt.xticks(rotation=60);
    # plt.ylim(0,250000)

    ax[1]=plt.subplot(1,2,2)
    ax[1]=plt.bar( x=df.iloc[:-1,0], height=df.iloc[:-1,2])

    plt.xticks(rotation=60);
    # plt.ylim(0,250000);

    plt.subplots_adjust(hspace=0);
    plt.subplots_adjust( wspace=0.2);
    # left=0.2, right=0.9, top=0.9, bottom=0.1,

# %%
case_count_sex=case_count('sex')
case_count_sex
# Out:
#                    sex   count   percent
# 0               Female  216977  0.525449
# 1                 Male  191513  0.463784
# 2      Unknown/Missing    4446  0.010767
# Total            Total  412936  1.000000

# %%
bar_plot2(case_count_sex)

# %%
case_count_race=case_count('race')
case_count_race
# Out:
#                                          race   count   percent
# 0                                       White  258077  0.624981
# 1                             Unknown/Missing   94896  0.229808
# 2                                       Black   45213  0.109492
# 3                                       Asian    6808  0.016487
# 4                              Multiple/Other    4555  0.011031
# 5               American Indian/Alaska Native    3256  0.007885
# 6      Native Hawaiian/Other Pacific Islander     131  0.000317
# Total                                   Total  412936  1.000000

# %%
bar_plot2(case_count_race)

# %%
case_count_ethnicity=case_count('ethnicity')
case_count_ethnicity
# Out:
#                  ethnicity   count   percent
# 0      Non-Hispanic/Latino  262518  0.635735
# 1          Unknown/Missing  117968  0.285681
# 2          Hispanic/Latino   32450  0.078584
# Total                Total  412936  1.000000

# %%
bar_plot2(case_count_ethnicity)

# %%
case_count_age=case_count('age_group')
case_count_age
# Out:
#             age_group   count   percent
# 0      18 to 49 years  226532  0.548589
# 1      50 to 64 years   72701  0.176059
# 2        0 - 17 years   60208  0.145805
# 3           65+ years   48668  0.117858
# 4             Missing    4827  0.011689
# Total           Total  412936  1.000000

# %%
bar_plot2(case_count_age)

# %%
df_surv1.head()
# Out:
#            res_state       age_group     sex   race            ethnicity  \
# case_month
# 2020-03-01        PA  18 to 49 years  Female  White  Non-Hispanic/Latino
# 2020-03-01        LA       65+ years    Male  Black  Non-Hispanic/Latino
# 2020-03-01        NJ  18 to 49 years  Female  Black  Non-Hispanic/Latino
# 2020-03-01        PA  18 to 49 years  Female  White  Non-Hispanic/Latino
# 2020-03-01        MI  18 to 49 years  Female  White  Non-Hispanic/Latino
#
#            symptom_status  hosp_yn   icu_yn death_yn
# case_month
# 2020-03-01    Symptomatic  Unknown  Unknown  Unknown
# 2020-03-01        Unknown  Unknown  Unknown  Missing
# 2020-03-01    Symptomatic  Missing  Missing       No
# 2020-03-01    Symptomatic       No       No       No
# 2020-03-01    Symptomatic       No  Missing       No

# %%
case_count_state=case_count('res_state')
case_count_state
# Out:
#       res_state   count   percent
# 0            TX   26791  0.064879
# 1            NC   22201  0.053764
# 2            PA   22135  0.053604
# 3            CA   21691  0.052529
# 4            FL   20441  0.049502
# 5            OH   20427  0.049468
# 6            NY   18046  0.043702
# 7            IL   16886  0.040893
# 8            GA   15496  0.037526
# 9            NJ   14973  0.036260
# 10           MI   14185  0.034352
# 11           IN   13972  0.033836
# 12           TN   12669  0.030680
# 13           SC   12567  0.030433
# 14           WI   11388  0.027578
# 15           LA   11194  0.027108
# 16           WA    9779  0.023682
# 17           MD    9671  0.023420
# 18           VA    9266  0.022439
# 19           MN    9158  0.022178
# 20           AL    8167  0.019778
# 21           MO    8129  0.019686
# 22           CO    7840  0.018986
# 23           AZ    7464  0.018075
# 24           MA    6587  0.015952
# 25           OR    5433  0.013157
# 26           UT    4996  0.012099
# 27           AR    4929  0.011936
# 28           NM    4720  0.011430
# 29           KS    3825  0.009263
# 30           ID    3703  0.008967
# 31           CT    3247  0.007863
# 32           NH    3038  0.007357
# 33           KY    3033  0.007345
# 34           ME    3014  0.007299
# 35           MT    2511  0.006081
# 36           RI    2386  0.005778
# 37           OK    2058  0.004984
# 38           DE    1956  0.004737
# 39           NE    1743  0.004221
# 40           ND    1740  0.004214
# 41           NV    1669  0.004042
# 42           HI    1627  0.003940
# 43           AK    1575  0.003814
# 44           SD    1478  0.003579
# 45           IA    1366  0.003308
# 46           WY     745  0.001804
# 47           VT     647  0.001567
# 48           DC     374  0.000906
# Total     Total  412936  1.000000

# %%
df_pop=pd.read_csv('../data/US_population_NST-EST2021-alldata.csv')

# %%
df_pop.head()
# Out:
#    SUMLEV REGION DIVISION  STATE              NAME  ESTIMATESBASE2020  \
# 0      10      0        0      0     United States          331449281
# 1      20      1        0      0  Northeast Region           57609148
# 2      20      2        0      0    Midwest Region           68985454
# 3      20      3        0      0      South Region          126266107
# 4      20      4        0      0       West Region           78588572
#
#    POPESTIMATE2020  POPESTIMATE2021  NPOPCHG_2020  NPOPCHG_2021  BIRTHS2020  \
# 0        331501080        331893745         51799        392665      893000
# 1         57525633         57159838        -83515       -365795      145067
# 2         68935174         68841444        -50280        -93730      190941
# 3        126409007        127225329        142900        816322      345546
# 4         78631266         78667134         42694         35868      211446
#
#    BIRTHS2021  DEATHS2020  DEATHS2021  NATURALINC2020  NATURALINC2021  \
# 0     3581986      853448     3433943           39552          148043
# 1      570592      148129      601644           -3062          -31052
# 2      748166      193237      761784           -2296          -13618
# 3     1416400      337628     1366769            7918           49631
# 4      846828      174454      703746           36992          143082
#
#    INTERNATIONALMIG2020  INTERNATIONALMIG2021  DOMESTICMIG2020  \
# 0                 12247                244622                0
# 1                  3314                 56046           -82743
# 2                  1678                 37835           -48944
# 3                  6553                112394           127901
# 4                   702                 38347             3786
#
#    DOMESTICMIG2021  NETMIG2020  NETMIG2021  RESIDUAL2020  RESIDUAL2021  \
# 0                0       12247      244622             0             0
# 1          -389638      -79429     -333592         -1024         -1151
# 2          -123103      -47266      -85268          -718          5156
# 3           657682      134454      770076           528         -3385
# 4          -144941        4488     -106594          1214          -620
#
#    RBIRTH2021  RDEATH2021  RNATURALINC2021  RINTERNATIONALMIG2021  \
# 0   10.798957   10.352637         0.446319               0.737485
# 1    9.950554   10.492070        -0.541516               0.977386
# 2   10.860566   11.058248        -0.197682               0.549222
# 3   11.168835   10.777476         0.391359               0.886268
# 4   10.767153    8.947910         1.819243               0.487570
#
#    RDOMESTICMIG2021  RNETMIG2021
# 0          0.000000     0.737485
# 1         -6.794897    -5.817511
# 2         -1.786994    -1.237772
# 3          5.186064     6.072332
# 4         -1.842880    -1.355309

# %%
df_pop['NAME'].value_counts()
# Out:
# United States           1
# Mississippi             1
# Montana                 1
# Nebraska                1
# Nevada                  1
# New Hampshire           1
# New Jersey              1
# New Mexico              1
# New York                1
# North Carolina          1
# North Dakota            1
# Ohio                    1
# Oklahoma                1
# Oregon                  1
# Pennsylvania            1
# Rhode Island            1
# South Carolina          1
# South Dakota            1
# Tennessee               1
# Texas                   1
# Utah                    1
# Vermont                 1
# Virginia                1
# Washington              1
# West Virginia           1
# Wisconsin               1
# Wyoming                 1
# Missouri                1
# Minnesota               1
# Northeast Region        1
# Michigan                1
# Midwest Region          1
# South Region            1
# West Region             1
# Alabama                 1
# Alaska                  1
# Arizona                 1
# Arkansas                1
# California              1
# Colorado                1
# Connecticut             1
# Delaware                1
# District of Columbia    1
# Florida                 1
# Georgia                 1
# Hawaii                  1
# Idaho                   1
# Illinois                1
# Indiana                 1
# Iowa                    1
# Kansas                  1
# Kentucky                1
# Louisiana               1
# Maine                   1
# Maryland                1
# Massachusetts           1
# Puerto Rico             1
# Name: NAME, dtype: int64

# %%
df_states=pd.read_csv('../data/US_state_two_letter_abbreviations.csv')

# %%
df_states.rename(columns={'State_ID': 'res_state'}, inplace=True)
df_states['res_state_name']=df_states['State']
df_states.drop(columns='State', inplace=True)

# %%
df_states.head()
# Out:
#   res_state res_state_name
# 0        AL        Alabama
# 1        AK         Alaska
# 2        AZ        Arizona
# 3        AR       Arkansas
# 4        CA     California

# %%
case_count_state1=pd.merge(case_count_state, df_states, on='res_state', how='outer')

# %%
case_count_state1.head()
# Out:
#   res_state    count   percent  res_state_name
# 0        TX  26791.0  0.064879           Texas
# 1        NC  22201.0  0.053764  North Carolina
# 2        PA  22135.0  0.053604    Pennsylvania
# 3        CA  21691.0  0.052529      California
# 4        FL  20441.0  0.049502         Florida

# %%
plt.figure(figsize=(20,15))
plt.barh( y=case_count_state.iloc[:-1,0], width=case_count_state.iloc[:-1,1])
# Out:
# <BarContainer object of 49 artists>

# %%
case_count_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to Total
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   res_state  50 non-null     object
#  1   count      50 non-null     int64
#  2   percent    50 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.6+ KB

# %%
df_surv1.head()
# Out:
#            res_state       age_group     sex   race            ethnicity  \
# case_month
# 2020-03-01        PA  18 to 49 years  Female  White  Non-Hispanic/Latino
# 2020-03-01        LA       65+ years    Male  Black  Non-Hispanic/Latino
# 2020-03-01        NJ  18 to 49 years  Female  Black  Non-Hispanic/Latino
# 2020-03-01        PA  18 to 49 years  Female  White  Non-Hispanic/Latino
# 2020-03-01        MI  18 to 49 years  Female  White  Non-Hispanic/Latino
#
#            symptom_status  hosp_yn   icu_yn death_yn
# case_month
# 2020-03-01    Symptomatic  Unknown  Unknown  Unknown
# 2020-03-01        Unknown  Unknown  Unknown  Missing
# 2020-03-01    Symptomatic  Missing  Missing       No
# 2020-03-01    Symptomatic       No       No       No
# 2020-03-01    Symptomatic       No  Missing       No

# %%
df_surv1.tail()
# Out:
#            res_state       age_group     sex     race            ethnicity  \
# case_month
# 2022-09-01        PA       65+ years  Female    White  Non-Hispanic/Latino
# 2022-09-01        OH    0 - 17 years    Male    White  Non-Hispanic/Latino
# 2022-09-01        MI    0 - 17 years  Female    White  Non-Hispanic/Latino
# 2022-09-01        NC  50 to 64 years    Male    White              Unknown
# 2022-09-01        CO       65+ years  Female  Missing  Non-Hispanic/Latino
#
#            symptom_status  hosp_yn   icu_yn death_yn
# case_month
# 2022-09-01    Symptomatic  Unknown  Unknown  Unknown
# 2022-09-01    Symptomatic  Missing  Missing       No
# 2022-09-01        Missing  Missing  Missing  Unknown
# 2022-09-01        Unknown  Unknown  Unknown       No
# 2022-09-01        Missing  Missing  Missing  Missing

# %%
#Help from https://stackoverflow.com/questions/28679930/how-to-drop-rows-from-pandas-data-frame-that-contains-a-particular-string-in-a-p#:~:text=If%20your%20string%20constraint%20is%20not%20just%20one,drop%20all%20rows%20containing%20elements%20of%20your%20list

df_surv1=df_surv[~df_surv.sex.str.contains('|'.join(['Missing','Unknown']))]
df_surv1=df_surv[~df_surv.age_group.str.contains('|'.join(['Missing','Unknown']))]
df_surv1=df_surv[~df_surv.race.str.contains('|'.join(['Missing','Unknown']))]
df_surv1=df_surv[~df_surv.ethnicity.str.contains('|'.join(['Missing','Unknown']))]

# %%
df_surv1.shape
# Out:
# (294968, 11)

# %%
df_surv1.age_group.value_counts()
# Out:
# 18 to 49 years    226532
# 50 to 64 years     72701
# 0 - 17 years       60208
# 65+ years          48668
# Name: age_group, dtype: int64

# %%
df_surv1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [105], in <cell line: 1>()
# ----> 1 df_surv1.head()
#
# NameError: name 'df_surv1' is not defined

# %% [markdown]
# ## COVID  cases and deaths by state over time

# %%
df_cases=pd.read_csv('../data/United_States_COVID-19_Cases_and_Deaths_by_State_over_Time.csv')

# %%
df_cases.head()
# Out:
#   submission_date state  tot_cases conf_cases prob_cases new_case pnew_case  \
# 0      01/25/2020    OR          0        NaN        NaN        0       NaN
# 1      09/17/2021    MD    516,784        NaN        NaN    1,525         0
# 2      10/12/2021    VT     33,388        NaN        NaN      112         5
# 3      02/01/2021    DC     37,008        NaN        NaN      136         0
# 4      12/19/2021    NC  1,586,243  1,339,055    247,188    3,410       466
#
#   tot_death conf_death prob_death new_death pnew_death  \
# 0         0        NaN        NaN         0        NaN
# 1    10,282     10,056        226        11          0
# 2       333        NaN        NaN         4          0
# 3       916        NaN        NaN         3          0
# 4    19,480     17,148      2,332        19          3
#
#                created_at consent_cases consent_deaths
# 0  03/26/2020 04:22:39 PM         Agree          Agree
# 1  09/19/2021 12:00:00 AM           NaN          Agree
# 2  10/14/2021 12:00:00 AM     Not agree      Not agree
# 3  02/02/2021 02:51:51 PM           NaN            NaN
# 4  12/19/2021 12:00:00 AM         Agree          Agree

# %%
#converting case_month to DateTime
# df_cases['submission_date']=pd.to_datetime(df_cases['submission_date'])

#setting case_month as index
# df_cases.set_index('submission_date', inplace=True)

#sorting index
# df_cases.sort_index(inplace=True)

# %%
df_cases.head()
# Out:
#   submission_date state  tot_cases conf_cases prob_cases new_case pnew_case  \
# 0      01/25/2020    OR          0        NaN        NaN        0       NaN
# 1      09/17/2021    MD    516,784        NaN        NaN    1,525         0
# 2      10/12/2021    VT     33,388        NaN        NaN      112         5
# 3      02/01/2021    DC     37,008        NaN        NaN      136         0
# 4      12/19/2021    NC  1,586,243  1,339,055    247,188    3,410       466
#
#   tot_death conf_death prob_death new_death pnew_death  \
# 0         0        NaN        NaN         0        NaN
# 1    10,282     10,056        226        11          0
# 2       333        NaN        NaN         4          0
# 3       916        NaN        NaN         3          0
# 4    19,480     17,148      2,332        19          3
#
#                created_at consent_cases consent_deaths
# 0  03/26/2020 04:22:39 PM         Agree          Agree
# 1  09/19/2021 12:00:00 AM           NaN          Agree
# 2  10/14/2021 12:00:00 AM     Not agree      Not agree
# 3  02/02/2021 02:51:51 PM           NaN            NaN
# 4  12/19/2021 12:00:00 AM         Agree          Agree

# %%
df_cases.tail();

# %%
df_cases.shape
# Out:
# (59640, 15)

# %%
# This code block will print the value counts for each column in the dataframe

list_of_columns_to_survey= df_cases.columns

for col_name in list_of_columns_to_survey:
    print('------  VALUE COUNTS ------------------')
    print(f'Column name: {col_name}')
    print(df_cases[col_name].value_counts())
    print('----------------------------------------')
# Out:
# ------  VALUE COUNTS ------------------
# Column name: submission_date
# 01/25/2020    60
# 08/20/2021    60
# 11/22/2020    60
# 12/23/2021    60
# 06/26/2022    60
#               ..
# 08/08/2022    60
# 05/26/2021    60
# 07/03/2022    60
# 06/08/2021    60
# 12/02/2021    60
# Name: submission_date, Length: 994, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: state
# OR     994
# MD     994
# AK     994
# IN     994
# NY     994
# PW     994
# IA     994
# TN     994
# HI     994
# MA     994
# GU     994
# MS     994
# GA     994
# AL     994
# RMI    994
# OK     994
# CO     994
# NYC    994
# MP     994
# OH     994
# AS     994
# PR     994
# SD     994
# PA     994
# TX     994
# ND     994
# NM     994
# WV     994
# WA     994
# AR     994
# UT     994
# KS     994
# FSM    994
# VT     994
# DC     994
# NC     994
# MI     994
# CT     994
# SC     994
# CA     994
# ID     994
# IL     994
# WY     994
# WI     994
# NH     994
# NV     994
# ME     994
# MO     994
# AZ     994
# RI     994
# LA     994
# VA     994
# MN     994
# KY     994
# NJ     994
# NE     994
# DE     994
# VI     994
# MT     994
# FL     994
# Name: state, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: tot_cases
# 0            4117
# 4             578
# 1             280
# 3             195
# 2             161
#              ...
# 3,675,728       1
# 1,767,143       1
# 325,272         1
# 1,400,814       1
# 165,109         1
# Name: tot_cases, Length: 42844, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: conf_cases
# 0            1044
# 4             471
# 1              79
# 9              67
# 14             53
#              ...
# 360,180         1
# 1,273,508       1
# 26,506          1
# 188,464         1
# 103,016         1
# Name: conf_cases, Length: 26036, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: prob_cases
# 0          7449
# 1,720       153
# 1            77
# 2            36
# 3            24
#            ...
# 7,554         1
# 136,580       1
# 47,893        1
# 13,445        1
# 4,405         1
# Name: prob_cases, Length: 19195, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: new_case
# 0         14040
# 1           346
# 2           277
# 3           185
# 4           167
#           ...
# 15,840        1
# 3,080         1
# 13,765        1
# 14,003        1
# 7,531         1
# Name: new_case, Length: 8121, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: pnew_case
# 0        27475
# 1          530
# 2          409
# 3          323
# 4          279
#          ...
# 1,576        1
# 2,364        1
# -239         1
# 3,865        1
# 2,582        1
# Name: pnew_case, Length: 3272, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: tot_death
# 0         6573
# 2          643
# 6          376
# 1          217
# 5          192
#           ...
# 18,286       1
# 51,470       1
# 7,120        1
# 86,579       1
# 3,201        1
# Name: tot_death, Length: 19096, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: conf_death
# 0         2345
# 2          590
# 34          94
# 3           77
# 17          71
#           ...
# 3,820        1
# 15,513       1
# 61,444       1
# 7,461        1
# 14,930       1
# Name: conf_death, Length: 14117, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: prob_death
# 0        8566
# 1         358
# 378       242
# 15        172
# 2         146
#          ...
# 7,831       1
# 1,634       1
# 5,119       1
# 3,406       1
# 1,112       1
# Name: prob_death, Length: 4398, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: new_death
# 0      23265
# 1       3245
# 2       2477
# 3       2056
# 4       1719
#        ...
# 277        1
# 463        1
# 678        1
# 345        1
# 441        1
# Name: new_death, Length: 502, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: pnew_death
# 0       40555
# 1        3750
# 2        2184
# 3        1512
# 4        1063
#         ...
# 199         1
# -231        1
# -154        1
# -140        1
# 476         1
# Name: pnew_death, Length: 324, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: created_at
# 03/26/2020 04:22:39 PM    2756
# 05/25/2020 03:38:40 PM     140
# 06/18/2021 01:48:26 PM      60
# 10/12/2022 01:14:18 PM      59
# 03/28/2020 04:22:39 PM      56
#                           ...
# 04/13/2021 09:53:09 AM       1
# 10/23/2020 09:44:31 AM       1
# 08/11/2021 04:43:51 PM       1
# 05/18/2020 12:01:54 PM       1
# 07/30/2021 11:05:02 AM       1
# Name: created_at, Length: 2209, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: consent_cases
# Agree        35744
# Not agree    13951
# Name: consent_cases, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: consent_deaths
# Agree        34872
# Not agree    15822
# Name: consent_deaths, dtype: int64
# ----------------------------------------

# %%
df_cases.head()
# Out:
#   submission_date state  tot_cases conf_cases prob_cases new_case pnew_case  \
# 0      01/25/2020    OR          0        NaN        NaN        0       NaN
# 1      09/17/2021    MD    516,784        NaN        NaN    1,525         0
# 2      10/12/2021    VT     33,388        NaN        NaN      112         5
# 3      02/01/2021    DC     37,008        NaN        NaN      136         0
# 4      12/19/2021    NC  1,586,243  1,339,055    247,188    3,410       466
#
#   tot_death conf_death prob_death new_death pnew_death  \
# 0         0        NaN        NaN         0        NaN
# 1    10,282     10,056        226        11          0
# 2       333        NaN        NaN         4          0
# 3       916        NaN        NaN         3          0
# 4    19,480     17,148      2,332        19          3
#
#                created_at consent_cases consent_deaths
# 0  03/26/2020 04:22:39 PM         Agree          Agree
# 1  09/19/2021 12:00:00 AM           NaN          Agree
# 2  10/14/2021 12:00:00 AM     Not agree      Not agree
# 3  02/02/2021 02:51:51 PM           NaN            NaN
# 4  12/19/2021 12:00:00 AM         Agree          Agree

# %%
df_cases_master=df_cases.copy()
df_cases=df_cases[['state','tot_cases','new_case','tot_death','new_death']]

# %%
df_cases.isnull().sum()
# Out:
# state        0
# tot_cases    0
# new_case     0
# tot_death    0
# new_death    0
# dtype: int64

# %%
df_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59640 entries, 0 to 59639
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   state      59640 non-null  object
#  1   tot_cases  59640 non-null  object
#  2   new_case   59640 non-null  object
#  3   tot_death  59640 non-null  object
#  4   new_death  59640 non-null  object
# dtypes: object(5)
# memory usage: 2.3+ MB

# %%
df_cases.to_csv('../data/clean_data/United_States_COVID-19_Cases_and_Deaths_by_State_over_Time_clean.csv', index=False)

# %% [markdown]
# ### Vaccination trends

# %%
df_vacc=pd.read_csv('../data/covid_vaccination_trends.csv', low_memory=False)

# %%
df_vacc.shape
# Out:
# (74160, 25)

# %%
df_vacc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74160 entries, 0 to 74159
# Data columns (total 25 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Date                                         74160 non-null  object
#  1   date_type                                    74160 non-null  object
#  2   MMWR_week                                    74160 non-null  int64
#  3   Location                                     74160 non-null  object
#  4   Administered_Daily                           74160 non-null  object
#  5   Administered_Cumulative                      74160 non-null  object
#  6   Administered_7_Day_Rolling_Average           73140 non-null  object
#  7   Admin_Dose_1_Daily                           74160 non-null  object
#  8   Admin_Dose_1_Cumulative                      74160 non-null  object
#  9   Admin_Dose_1_Day_Rolling_Average             73140 non-null  object
#  10  Administered_Dose1_Pop_Pct                   74160 non-null  float64
#  11  Administered_daily_change_report             67500 non-null  object
#  12  Administered_daily_change_report_7dayroll    66420 non-null  object
#  13  Series_Complete_Daily                        74160 non-null  object
#  14  Series_Complete_Cumulative                   74160 non-null  object
#  15  Series_Complete_Day_Rolling_Average          73140 non-null  object
#  16  Series_Complete_Pop_Pct                      74160 non-null  float64
#  17  Booster_Daily                                74160 non-null  object
#  18  Booster_Cumulative                           74160 non-null  object
#  19  Booster_7_Day_Rolling_Average                73140 non-null  object
#  20  Additional_Doses_Vax_Pct                     74160 non-null  float64
#  21  Second_Booster_50Plus_Daily                  74160 non-null  object
#  22  Second_Booster_50Plus_Cumulative             74160 non-null  object
#  23  Second_Booster_50Plus_7_Day_Rolling_Average  73140 non-null  object
#  24  Second_Booster_50Plus_Vax_Pct                74160 non-null  float64
# dtypes: float64(4), int64(1), object(20)
# memory usage: 14.1+ MB

# %%
df_vacc.head()
# Out:
#          Date date_type  MMWR_week Location Administered_Daily  \
# 0  10/12/2022    Report         41       DE             17,883
# 1  10/12/2022    Report         41       CT              5,733
# 2  10/12/2022    Report         41       CA              3,409
# 3  10/12/2022    Report         41       NE             21,694
# 4  10/12/2022    Report         41       PW                152
#
#   Administered_Cumulative Administered_7_Day_Rolling_Average  \
# 0               2,005,782                                NaN
# 1               8,273,306                                NaN
# 2              81,763,386                                NaN
# 3               3,489,100                                NaN
# 4                  49,838                                NaN
#
#   Admin_Dose_1_Daily Admin_Dose_1_Cumulative Admin_Dose_1_Day_Rolling_Average  \
# 0              1,841                 839,722                              NaN
# 1              5,198               3,534,406                              NaN
# 2            170,547              33,585,368                              NaN
# 3              1,355               1,396,070                              NaN
# 4                  9                  20,625                              NaN
#
#    ...  Series_Complete_Day_Rolling_Average Series_Complete_Pop_Pct  \
# 0  ...                                  NaN                    71.7
# 1  ...                                  NaN                    81.5
# 2  ...                                  NaN                    74.1
# 3  ...                                  NaN                    65.2
# 4  ...                                  NaN                    85.4
#
#   Booster_Daily Booster_Cumulative Booster_7_Day_Rolling_Average  \
# 0         2,245            344,388                           NaN
# 1         1,052          1,567,645                           NaN
# 2      -130,515         16,291,249                           NaN
# 3         1,835            677,307                           NaN
# 4            32             12,133                           NaN
#
#   Additional_Doses_Vax_Pct  Second_Booster_50Plus_Daily  \
# 0                     49.3                        4,311
# 1                     54.0                          492
# 2                     55.7                      -40,176
# 3                     53.7                        4,749
# 4                     66.0                           19
#
#   Second_Booster_50Plus_Cumulative  \
# 0                           96,891
# 1                          374,525
# 2                        3,578,567
# 3                          161,952
# 4                            1,194
#
#   Second_Booster_50Plus_7_Day_Rolling_Average Second_Booster_50Plus_Vax_Pct
# 0                                         NaN                          42.0
# 1                                         NaN                          40.4
# 2                                         NaN                          42.9
# 3                                         NaN                          40.2
# 4                                         NaN                          24.7
#
# [5 rows x 25 columns]

# %%
df_vacc.isnull().sum()
# Out:
# Date                                              0
# date_type                                         0
# MMWR_week                                         0
# Location                                          0
# Administered_Daily                                0
# Administered_Cumulative                           0
# Administered_7_Day_Rolling_Average             1020
# Admin_Dose_1_Daily                                0
# Admin_Dose_1_Cumulative                           0
# Admin_Dose_1_Day_Rolling_Average               1020
# Administered_Dose1_Pop_Pct                        0
# Administered_daily_change_report               6660
# Administered_daily_change_report_7dayroll      7740
# Series_Complete_Daily                             0
# Series_Complete_Cumulative                        0
# Series_Complete_Day_Rolling_Average            1020
# Series_Complete_Pop_Pct                           0
# Booster_Daily                                     0
# Booster_Cumulative                                0
# Booster_7_Day_Rolling_Average                  1020
# Additional_Doses_Vax_Pct                          0
# Second_Booster_50Plus_Daily                       0
# Second_Booster_50Plus_Cumulative                  0
# Second_Booster_50Plus_7_Day_Rolling_Average    1020
# Second_Booster_50Plus_Vax_Pct                     0
# dtype: int64

# %%
df_vacc.dropna(inplace=True)

# %%
df_vacc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66420 entries, 7740 to 74159
# Data columns (total 25 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Date                                         66420 non-null  object
#  1   date_type                                    66420 non-null  object
#  2   MMWR_week                                    66420 non-null  int64
#  3   Location                                     66420 non-null  object
#  4   Administered_Daily                           66420 non-null  object
#  5   Administered_Cumulative                      66420 non-null  object
#  6   Administered_7_Day_Rolling_Average           66420 non-null  object
#  7   Admin_Dose_1_Daily                           66420 non-null  object
#  8   Admin_Dose_1_Cumulative                      66420 non-null  object
#  9   Admin_Dose_1_Day_Rolling_Average             66420 non-null  object
#  10  Administered_Dose1_Pop_Pct                   66420 non-null  float64
#  11  Administered_daily_change_report             66420 non-null  object
#  12  Administered_daily_change_report_7dayroll    66420 non-null  object
#  13  Series_Complete_Daily                        66420 non-null  object
#  14  Series_Complete_Cumulative                   66420 non-null  object
#  15  Series_Complete_Day_Rolling_Average          66420 non-null  object
#  16  Series_Complete_Pop_Pct                      66420 non-null  float64
#  17  Booster_Daily                                66420 non-null  object
#  18  Booster_Cumulative                           66420 non-null  object
#  19  Booster_7_Day_Rolling_Average                66420 non-null  object
#  20  Additional_Doses_Vax_Pct                     66420 non-null  float64
#  21  Second_Booster_50Plus_Daily                  66420 non-null  object
#  22  Second_Booster_50Plus_Cumulative             66420 non-null  object
#  23  Second_Booster_50Plus_7_Day_Rolling_Average  66420 non-null  object
#  24  Second_Booster_50Plus_Vax_Pct                66420 non-null  float64
# dtypes: float64(4), int64(1), object(20)
# memory usage: 13.2+ MB

# %%
df_vacc.head()
# Out:
#             Date date_type  MMWR_week Location Administered_Daily  \
# 7740  06/21/2022     Admin         25       ND                509
# 7741  06/21/2022     Admin         25       CA             40,018
# 7742  06/21/2022     Admin         25       IA              2,539
# 7743  06/21/2022     Admin         25       AR              2,027
# 7744  06/21/2022     Admin         25       MI              6,310
#
#      Administered_Cumulative Administered_7_Day_Rolling_Average  \
# 7740               1,131,991                                438
# 7741              77,624,034                             35,217
# 7742               5,276,550                              2,036
# 7743               4,363,089                              1,616
# 7744              16,386,296                              5,279
#
#      Admin_Dose_1_Daily Admin_Dose_1_Cumulative  \
# 7740                 91                 504,634
# 7741              6,980              32,940,724
# 7742                365               2,159,525
# 7743                356               2,036,932
# 7744                895               6,743,028
#
#      Admin_Dose_1_Day_Rolling_Average  ...  \
# 7740                               74  ...
# 7741                            4,604  ...
# 7742                              214  ...
# 7743                              295  ...
# 7744                              652  ...
#
#       Series_Complete_Day_Rolling_Average Series_Complete_Pop_Pct  \
# 7740                                   52                    56.3
# 7741                                3,597                    72.9
# 7742                                  186                    62.6
# 7743                                  221                    55.2
# 7744                                  554                    60.8
#
#      Booster_Daily Booster_Cumulative Booster_7_Day_Rolling_Average  \
# 7740           120            189,296                            96
# 7741        11,490         15,518,543                        11,000
# 7742           484          1,065,873                           418
# 7743           462            683,622                           382
# 7744         1,543          3,360,001                         1,328
#
#      Additional_Doses_Vax_Pct  Second_Booster_50Plus_Daily  \
# 7740                     44.1                          193
# 7741                     53.9                       15,935
# 7742                     54.0                        1,408
# 7743                     41.1                          876
# 7744                     55.4                        3,132
#
#      Second_Booster_50Plus_Cumulative  \
# 7740                           18,578
# 7741                        2,512,239
# 7742                          202,036
# 7743                          108,487
# 7744                          597,299
#
#      Second_Booster_50Plus_7_Day_Rolling_Average Second_Booster_50Plus_Vax_Pct
# 7740                                         177                          15.2
# 7741                                      14,385                          31.1
# 7742                                       1,168                          28.8
# 7743                                         677                          23.3
# 7744                                       2,627                          27.7
#
# [5 rows x 25 columns]

# %% [markdown]
# ### convert column (17,18,19,21,22,23) and some others to integer type

# %%
df_vacc.shape
# Out:
# (66420, 25)

# %%
# This code block will print the value counts for each column in the dataframe

list_of_columns_to_survey= df_vacc.columns

for col_name in list_of_columns_to_survey:
    print('------  VALUE COUNTS ------------------')
    print(f'Column name: {col_name}')
    print(df_vacc[col_name].value_counts())
    print('----------------------------------------')
# Out:
# ------  VALUE COUNTS ------------------
# Column name: Date
# 09/16/2021    120
# 06/13/2021    120
# 06/19/2021    120
# 06/18/2021    120
# 06/17/2021    120
#              ...
# 06/18/2022     60
# 06/19/2022     60
# 06/20/2022     60
# 06/17/2022     60
# 06/21/2022     60
# Name: Date, Length: 556, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: date_type
# Admin     33360
# Report    33060
# Name: date_type, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: MMWR_week
# 51    1680
# 11    1680
# 1     1680
# 2     1680
# 3     1680
# 4     1680
# 5     1680
# 6     1680
# 7     1680
# 8     1680
# 9     1680
# 10    1680
# 12    1680
# 13    1680
# 14    1680
# 15    1680
# 16    1680
# 17    1680
# 18    1680
# 19    1680
# 20    1680
# 21    1680
# 22    1680
# 23    1680
# 52    1680
# 24    1560
# 25    1020
# 50     840
# 49     840
# 26     840
# 27     840
# 28     840
# 29     840
# 30     840
# 31     840
# 32     840
# 33     840
# 34     840
# 35     840
# 36     840
# 37     840
# 38     840
# 39     840
# 40     840
# 41     840
# 42     840
# 43     840
# 44     840
# 45     840
# 46     840
# 47     840
# 48     840
# 53     840
# Name: MMWR_week, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Location
# ND    1107
# CA    1107
# NC    1107
# KS    1107
# TN    1107
# DC    1107
# AK    1107
# IL    1107
# DE    1107
# CT    1107
# WA    1107
# CO    1107
# WI    1107
# MD    1107
# AL    1107
# MP    1107
# AZ    1107
# MH    1107
# VA    1107
# OH    1107
# FL    1107
# GA    1107
# SD    1107
# MT    1107
# MA    1107
# NV    1107
# VT    1107
# NM    1107
# ME    1107
# WV    1107
# RI    1107
# KY    1107
# ID    1107
# IA    1107
# AR    1107
# MI    1107
# TX    1107
# IN    1107
# OR    1107
# MN    1107
# PA    1107
# NY    1107
# MO    1107
# PR    1107
# US    1107
# MS    1107
# SC    1107
# FM    1107
# GU    1107
# PW    1107
# NJ    1107
# AS    1107
# NH    1107
# UT    1107
# WY    1107
# OK    1107
# NE    1107
# VI    1107
# LA    1107
# HI    1107
# Name: Location, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Administered_Daily
# 0         3137
# 1          254
# 2          161
# 3          117
# 4           93
#           ...
# 80,808       1
# 61,706       1
# 28,188       1
# 5,478        1
# 38,970       1
# Name: Administered_Daily, Length: 30415, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Administered_Cumulative
# 0             308
# 3,791          24
# 49,506         21
# 1              18
# 19             17
#              ...
# 2,431,946       1
# 3,954,456       1
# 10,037,526      1
# 2,142,391       1
# 820             1
# Name: Administered_Cumulative, Length: 62874, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Administered_7_Day_Rolling_Average
# 0         418
# 1          42
# 48         41
# 86         36
# 93         34
#          ...
# 25,923      1
# 54,189      1
# 45,703      1
# 4,127       1
# 38,970      1
# Name: Administered_7_Day_Rolling_Average, Length: 31134, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Admin_Dose_1_Daily
# 0          5442
# 1           429
# 2           233
# 3           159
# 4           115
#            ...
# 9,351         1
# 13,852        1
# 19,007        1
# 182,016       1
# 31,753        1
# Name: Admin_Dose_1_Daily, Length: 20030, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Admin_Dose_1_Cumulative
# 0            3625
# 19             16
# 1              15
# 20,456         12
# 45,546         12
#              ...
# 3,864,923       1
# 5,726,746       1
# 62,918          1
# 9,034,415       1
# 836             1
# Name: Admin_Dose_1_Cumulative, Length: 60407, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Admin_Dose_1_Day_Rolling_Average
# 0         3739
# 1          197
# 2          145
# 4          110
# 5          101
#           ...
# 8,853        1
# 11,981       1
# 11,682       1
# 11,260       1
# 1,382        1
# Name: Admin_Dose_1_Day_Rolling_Average, Length: 20692, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Administered_Dose1_Pop_Pct
# 95.00    1559
# 0.00     1296
# 65.50     200
# 65.70     197
# 65.80     192
#          ...
# 6.41        1
# 6.61        1
# 10.77       1
# 8.13        1
# 4.04        1
# Name: Administered_Dose1_Pop_Pct, Length: 1455, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Administered_daily_change_report
# 0         33481
# 1           142
# 2            82
# 3            57
# 4            40
#           ...
# 8,865         1
# 10,019        1
# 19,224        1
# 28,967        1
# 38,970        1
# Name: Administered_daily_change_report, Length: 19546, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Administered_daily_change_report_7dayroll
# 0         418
# 1          42
# 48         41
# 86         36
# 93         34
#          ...
# 25,923      1
# 54,189      1
# 45,703      1
# 4,127       1
# 38,970      1
# Name: Administered_daily_change_report_7dayroll, Length: 31134, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Series_Complete_Daily
# 0         7154
# 1          480
# 2          340
# 3          212
# 5          186
#           ...
# 8,271        1
# 15,573       1
# 21,511       1
# 34,760       1
# 8,042        1
# Name: Series_Complete_Daily, Length: 18247, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Series_Complete_Cumulative
# 0            5010
# 1              48
# 4              29
# 9              27
# 2              21
#              ...
# 476,149         1
# 1,859,089       1
# 1,018,227       1
# 2,333,639       1
# 8,152           1
# Name: Series_Complete_Cumulative, Length: 58230, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Series_Complete_Day_Rolling_Average
# 0          5241
# 1           211
# 2           193
# 3           177
# 6           168
#            ...
# 617,703       1
# 22,091        1
# 14,237        1
# 8,079         1
# 10,944        1
# Name: Series_Complete_Day_Rolling_Average, Length: 18794, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Series_Complete_Pop_Pct
# 0.0     6682
# 54.4     217
# 54.7     213
# 54.6     211
# 54.9     208
#         ...
# 86.1       1
# 86.2       1
# 86.5       1
# 86.8       1
# 87.2       1
# Name: Series_Complete_Pop_Pct, Length: 886, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Booster_Daily
# 0         34721
# 1           370
# 2           147
# 3           118
# 4           108
#           ...
# 15,365        1
# 19,683        1
# 19,654        1
# 18,484        1
# 2,428         1
# Name: Booster_Daily, Length: 11805, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Booster_Cumulative
# 0            29503
# 1             2214
# 2              618
# 3              421
# 4              286
#              ...
# 284,223          1
# 1,618,340        1
# 784,741          1
# 2,857,975        1
# 45               1
# Name: Booster_Cumulative, Length: 30984, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Booster_7_Day_Rolling_Average
# 0         33506
# 2           109
# 10          104
# 1            96
# 6            67
#           ...
# 19,029        1
# 24,069        1
# 14,825        1
# 5,198         1
# 7,583         1
# Name: Booster_7_Day_Rolling_Average, Length: 12500, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Additional_Doses_Vax_Pct
# 0.0     33517
# 0.1       378
# 1.0       161
# 0.7       159
# 1.1       156
#         ...
# 63.3        1
# 64.1        1
# 64.3        1
# 64.0        1
# 63.1        1
# Name: Additional_Doses_Vax_Pct, Length: 643, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Second_Booster_50Plus_Daily
# 0         48504
# 1           636
# 2           482
# 3           431
# 4           364
#           ...
# 7,825         1
# 11,443        1
# 7,733         1
# 13,251        1
# 616           1
# Name: Second_Booster_50Plus_Daily, Length: 4156, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Second_Booster_50Plus_Cumulative
# 0          46806
# 2            239
# 1            235
# 3            186
# 4            116
#            ...
# 291,393        1
# 466,314        1
# 52,667         1
# 32,679         1
# 1,764          1
# Name: Second_Booster_50Plus_Cumulative, Length: 12521, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Second_Booster_50Plus_7_Day_Rolling_Average
# 0         48028
# 1           570
# 2           423
# 3           302
# 5           299
#           ...
# 7,199         1
# 3,182         1
# 3,005         1
# 88,256        1
# 667           1
# Name: Second_Booster_50Plus_7_Day_Rolling_Average, Length: 4398, dtype: int64
# ----------------------------------------
# ------  VALUE COUNTS ------------------
# Column name: Second_Booster_50Plus_Vax_Pct
# 0.0     47162
# 0.2      1322
# 0.1      1286
# 0.3      1141
# 0.8       963
#         ...
# 37.6        1
# 37.4        1
# 36.6        1
# 37.2        1
# 36.7        1
# Name: Second_Booster_50Plus_Vax_Pct, Length: 373, dtype: int64
# ----------------------------------------

# %%
df_vacc.describe()
# Out:
#           MMWR_week  Administered_Dose1_Pop_Pct  Series_Complete_Pop_Pct  \
# count  66420.000000                66420.000000             66420.000000
# mean      23.218609                   53.794680                44.673245
# std       15.365320                   25.899333                24.339396
# min        1.000000                    0.000000                 0.000000
# 25%       10.000000                   39.100000                29.100000
# 50%       20.000000                   59.850000                51.600000
# 75%       36.000000                   71.800000                62.000000
# max       53.000000                  100.000000                88.800000
#
#        Additional_Doses_Vax_Pct  Second_Booster_50Plus_Vax_Pct
# count              66420.000000                   66420.000000
# mean                  16.251596                       1.862185
# std                   20.465388                       5.726777
# min                    0.000000                       0.000000
# 25%                    0.000000                       0.000000
# 50%                    0.000000                       0.000000
# 75%                   37.800000                       0.300000
# max                   64.500000                      37.600000

# %%
df_vacc.to_csv('../data/clean_data/covid_vaccination_trends_clean.csv', index=False)
