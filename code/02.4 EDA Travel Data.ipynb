# %%
import pandas as pd 
import missingno as msno
import matplotlib.pyplot as plt

# %%
travel = pd.read_csv('../data/Trips_by_Distance.csv')
travel.head(3)
# Out:
#       Level        Date  State FIPS State Postal Code  County FIPS  \
# 0  National  2019/01/01         NaN               NaN          NaN
# 1  National  2019/01/02         NaN               NaN          NaN
# 2  National  2019/01/03         NaN               NaN          NaN
#
#   County Name  Population Staying at Home  Population Not Staying at Home  \
# 0         NaN                  77433867.0                     248733553.0
# 1         NaN                  61305201.0                     264862219.0
# 2         NaN                  63050480.0                     263116940.0
#
#    Number of Trips  Number of Trips <1  ...  Number of Trips 5-10  \
# 0     8.977844e+08         241667151.0  ...           129670778.0
# 1     1.139452e+09         291276735.0  ...           171637514.0
# 2     1.162753e+09         296375014.0  ...           175775410.0
#
#    Number of Trips 10-25  Number of Trips 25-50  Number of Trips 50-100  \
# ...

# %%
travel['Level'].value_counts()
# Out:
# County      3556744
# State         57732
# National       1132
# Name: Level, dtype: int64

# %%
travel.isnull().sum()
# Out:
# Level                                 0
# Date                                  0
# State FIPS                         1132
# State Postal Code                  1132
# County FIPS                       58864
# County Name                       58864
# Population Staying at Home        31990
# Population Not Staying at Home    31990
# Number of Trips                   31990
# Number of Trips <1                31990
# Number of Trips 1-3               31990
# Number of Trips 3-5               31990
# Number of Trips 5-10              31990
# Number of Trips 10-25             31990
# Number of Trips 25-50             31990
# Number of Trips 50-100            31990
# Number of Trips 100-250           31990
# Number of Trips 250-500           31990
# Number of Trips >=500             31990
# Row ID                                0
# Week                                  0
# Month                                 0
# dtype: int64

# %%
travel.shape
# Out:
# (3615608, 22)

# %%
msno.matrix(travel);

# %%
travel.dropna(inplace=True)

# %%
travel.shape
# Out:
# (3524754, 22)

# %%
travel.to_csv('../data/clean_data/travel_data_clean.csv')

# %%
travel['Date'] = pd.to_datetime(travel['Date'])

travel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3524754 entries, 21061 to 3615243
# Data columns (total 22 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   Level                           object
#  1   Date                            datetime64[ns]
#  2   State FIPS                      float64
#  3   State Postal Code               object
#  4   County FIPS                     float64
#  5   County Name                     object
#  6   Population Staying at Home      float64
#  7   Population Not Staying at Home  float64
#  8   Number of Trips                 float64
#  9   Number of Trips <1              float64
#  10  Number of Trips 1-3             float64
#  11  Number of Trips 3-5             float64
#  12  Number of Trips 5-10            float64
#  13  Number of Trips 10-25           float64
#  14  Number of Trips 25-50           float64
#  15  Number of Trips 50-100          float64
# ...

# %%
travel.set_index('Date', inplace=True)
travel
# Out:
#              Level  State FIPS State Postal Code  County FIPS  \
# Date
# 2021-06-06  County        56.0                WY      56045.0
# 2021-06-06  County         5.0                AR       5011.0
# 2021-06-06  County         5.0                AR       5013.0
# 2021-06-06  County         5.0                AR       5015.0
# 2021-06-06  County         5.0                AR       5017.0
# ...            ...         ...               ...          ...
# 2022-02-05  County         1.0                AL       1067.0
# 2022-02-05  County         1.0                AL       1069.0
# 2022-02-05  County         1.0                AL       1071.0
# 2022-02-05  County         1.0                AL       1073.0
# 2022-02-05  County         1.0                AL       1075.0
#
#                  County Name  Population Staying at Home  \
# Date
# 2021-06-06     Weston County                      1268.0
# 2021-06-06    Bradley County                      1780.0
# ...

# %%
travel =travel.groupby(by=travel.index).sum()
travel = travel.resample('W').mean()

# %%
df_not_home = travel#.loc['2021-09':'2022-09']
plt.figure(figsize=(18,4))
plt.plot(df_not_home['Population Staying at Home'].rolling(window=1).mean())

# %%
plt.figure(figsize=(18,4))

# %%
travel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 162 entries, 2019-01-06 to 2022-02-06
# Freq: W-SUN
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   State FIPS                      162 non-null    float64
#  1   County FIPS                     162 non-null    float64
#  2   Population Staying at Home      162 non-null    float64
#  3   Population Not Staying at Home  162 non-null    float64
#  4   Number of Trips                 162 non-null    float64
#  5   Number of Trips <1              162 non-null    float64
#  6   Number of Trips 1-3             162 non-null    float64
#  7   Number of Trips 3-5             162 non-null    float64
#  8   Number of Trips 5-10            162 non-null    float64
#  9   Number of Trips 10-25           162 non-null    float64
#  10  Number of Trips 25-50           162 non-null    float64
# ...
